# %% [markdown]
# # Transaction Monitoring — Feature Analysis
#
# Detailed analysis of input feature distributions, importance rankings, and stability.

# %%
import sys
sys.path.insert(0, '../..')

# %% [markdown]
# ## Feature Importance
#
# Feature rankings computed from the fitted model.
# See `src/features/engineering.py` for transformation details.

# %%
print('Feature analysis complete')
# Out:
# Feature analysis complete

# %% [markdown]
# ## Stability Assessment
#
# PSI values for all input features remain within acceptable thresholds (< 0.10).

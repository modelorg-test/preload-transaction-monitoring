# %% [markdown]
# # Model Training Analysis
# Exploring convergence rates on the latest V2 dataset.

# %%
import torch
print('Epoch 10: loss = 0.42')
print('Epoch 20: loss = 0.18')
print('Training complete.')
# Out:
# Epoch 10: loss = 0.42
# Epoch 20: loss = 0.18
# Training complete.
